# %%
import pandas as pd

# %%
liked = pd.read_csv('data/liked_recipes.csv')
liked
# Out:
#                                          ingredients  \
# 0  ['1 pound lean ground beef', '2 tablespoons dr...
# 1  ['1 (14 ounce) can sweetened condensed milk (s...
# 2  ['1 ½ cups rolled oats', '1 ½ cups sifted past...
# 3  ['cooking spray', '½ cup milk', '½ cup all-pur...
# 4  ['3 tablespoons olive oil, divided', '1 pound ...
# 5  ["9  Hawaiian bread rolls (such as King's®), s...
#
#                                           directions  \
# 0  ['Heat a large skillet over medium-high heat. ...
# 1  ['Preheat the oven to 350 degrees F (175 degre...
# 2  ['Preheat the oven to 350 degrees F (175 degre...
# 3  ['Preheat oven to 400 degrees F (200 degrees C...
# 4  ['Heat 2 tablespoons of olive oil in a large p...
# 5  ["Set oven rack about 6 inches from the heat s...
#
#                                       image_filename  \
# 0       5410153-e9807f995fb74fe58bd2fcd56b541010.jpg
# 1  9281485-authentic-mexican-corn-bread-Lisa-Lode...
# ...

# %%
disliked = pd.read_csv('data/disliked_recipes.csv')
disliked
# Out:
#                                          ingredients  \
# 0  ['1 pound lean ground beef', '2 tablespoons dr...
# 1  ['1 (14 ounce) can sweetened condensed milk (s...
#
#                                           directions  \
# 0  ['Heat a large skillet over medium-high heat. ...
# 1  ['Preheat the oven to 350 degrees F (175 degre...
#
#                                       image_filename  \
# 0       5410153-e9807f995fb74fe58bd2fcd56b541010.jpg
# 1  9281485-authentic-mexican-corn-bread-Lisa-Lode...
#
#                                         category_url  \
# 0  https://www.allrecipes.com/recipes/14930/main-...
# 1  https://www.allrecipes.com/recipes/342/bread/q...
#
#                           title category  rating  rating_count cook_time  \
# 0    Grilled Cheese Sloppy Joes  Recipes     4.8             4      1 hr
# 1  Authentic Mexican Corn Bread  Recipes     4.3            50   45 mins
#
#      total_time            yield  servings  calories  fat carbs protein
# ...
