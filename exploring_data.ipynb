# %%
import pandas as pd
import nltk
from tqdm import tqdm

# %%
def open_json(file_path: str):
    with open(file_path, 'r') as file:
        return json.load(file)

# %%
data = pd.read_csv('data/recipe_data.csv')
data
# Out:
#                                              ingredients  \
# 0      ['½ cup (63 g) all-purpose flour', '¼ cup (50 ...
# 1      ['4 large red plums (about 1 lb.), cut into ½"...
# 2      ['2 heads of Little Gem lettuce, trimmed, quar...
# 3      ['3 large egg yolks', '4 oz. Pecorino Romano, ...
# 4      ['2 large eggs', '10 Tbsp. unsalted butter, me...
# ...                                                  ...
# 23976  ['1 ⅓ cups French-fried onions, crushed', '1 l...
# 23977  ['2  summer squash, ends trimmed', '¼ cup oliv...
# 23978  ['1 (8 ounce) container ricotta cheese', '2 la...
# 23979  ['2 cups sliced fresh peaches', '2 cups sliced...
# 23980  ['2 cups all-purpose flour', '1 cup white suga...
#
#                                               directions  \
# 0      ['Streusel - Step 1: Whisk , , , and in a medi...
# 1      ['None - Step 1: Bring , , , , and ¼ cup water...
# 2      ['None - Step 1: Place , in a large bowl and c...
# 3      ['None - Step 1: Whisk and , in a medium bowl ...
# 4      ['None - Step 1: Preheat oven to 375°. Line a ...
# ...                                                  ...
# 23976  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23977  ['Preheat the oven to 450 degrees F (230 degre...
# 23978  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23979  ['Preheat oven to 350 degrees F (175 degrees C...
# 23980  ['Preheat the oven to 350 degrees F (175 degre...
#
#                                                title  rating  \
# 0                       Butternut Squash Coffee Cake     4.0
# 1                   Jammy Cumin Plums and Feta Salad     4.7
# 2                     Cheese-Cracker-Crusted Chicken     4.8
# 3                Easy, Cheesy, Almost-Carbonara Udon     5.0
# 4      Butternut Squash, Coconut, and Ginger Muffins     4.4
# ...                                              ...     ...
# 23976                   Crunchy French Onion Chicken     4.5
# 23977                          Roasted Summer Squash     4.7
# 23978                                Ricotta Gnocchi     4.5
# 23979                     Fresh Fruit Basket Cobbler     4.5
# 23980                                 Cinnamon Bread     4.6
#
#               total_time       servings  calories  fat carbs protein  \
# 0      1 hour 20 minutes  8–12 servings       NaN  NaN   NaN     NaN
# 1                 1 hour     4 servings       NaN  NaN   NaN     NaN
# 2                    NaN     4 servings       NaN  NaN   NaN     NaN
# 3             30 minutes     4 servings       NaN  NaN   NaN     NaN
# 4                    NaN  Makes 1 dozen       NaN  NaN   NaN     NaN
# ...                  ...            ...       ...  ...   ...     ...
# 23976            30 mins              4     623.0  40g   32g     28g
# 23977            20 mins              4     139.0  14g    4g      1g
# 23978               1 hr              5     442.0  26g   27g     22g
# 23979               1 hr              8     358.0   8g   69g      5g
# 23980       1 hr 10 mins             12     218.0   6g   36g      4g
#
#         category rating_count cook_time              yield  ingredient_count
# 0            NaN          NaN       NaN                NaN                18
# 1            NaN          NaN       NaN                NaN                 8
# 2            NaN          NaN       NaN                NaN                13
# 3            NaN          NaN       NaN                NaN                 9
# 4            NaN          NaN       NaN                NaN                13
# ...          ...          ...       ...                ...               ...
# 23976    Recipes          339   20 mins                NaN                 3
# 23977  Side Dish           71    5 mins                NaN                 5
# 23978    Recipes          712   15 mins                NaN                14
# 23979    Recipes            2   20 mins   1 8x13-inch dish                10
# 23980    Recipes        1,154   50 mins  1 (9x5-inch) loaf                13
#
# [23981 rows x 15 columns]

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

def count_verbs(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    return sum(1 for word, pos in pos_tags if pos.startswith('VB'))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\romer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\romer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data['verb_count'] = data['directions'].apply(count_verbs)
# Out:
# 100%|██████████| 23981/23981 [06:57<00:00, 57.44it/s]

# %%
data
# Out:
#                                              ingredients  \
# 0      ['½ cup (63 g) all-purpose flour', '¼ cup (50 ...
# 1      ['4 large red plums (about 1 lb.), cut into ½"...
# 2      ['2 heads of Little Gem lettuce, trimmed, quar...
# 3      ['3 large egg yolks', '4 oz. Pecorino Romano, ...
# 4      ['2 large eggs', '10 Tbsp. unsalted butter, me...
# ...                                                  ...
# 23976  ['1 ⅓ cups French-fried onions, crushed', '1 l...
# 23977  ['2  summer squash, ends trimmed', '¼ cup oliv...
# 23978  ['1 (8 ounce) container ricotta cheese', '2 la...
# 23979  ['2 cups sliced fresh peaches', '2 cups sliced...
# 23980  ['2 cups all-purpose flour', '1 cup white suga...
#
#                                               directions  \
# 0      ['Streusel - Step 1: Whisk , , , and in a medi...
# 1      ['None - Step 1: Bring , , , , and ¼ cup water...
# 2      ['None - Step 1: Place , in a large bowl and c...
# 3      ['None - Step 1: Whisk and , in a medium bowl ...
# 4      ['None - Step 1: Preheat oven to 375°. Line a ...
# ...                                                  ...
# 23976  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23977  ['Preheat the oven to 450 degrees F (230 degre...
# 23978  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23979  ['Preheat oven to 350 degrees F (175 degrees C...
# 23980  ['Preheat the oven to 350 degrees F (175 degre...
#
#                                                title  rating  \
# 0                       Butternut Squash Coffee Cake     4.0
# 1                   Jammy Cumin Plums and Feta Salad     4.7
# 2                     Cheese-Cracker-Crusted Chicken     4.8
# 3                Easy, Cheesy, Almost-Carbonara Udon     5.0
# 4      Butternut Squash, Coconut, and Ginger Muffins     4.4
# ...                                              ...     ...
# 23976                   Crunchy French Onion Chicken     4.5
# 23977                          Roasted Summer Squash     4.7
# 23978                                Ricotta Gnocchi     4.5
# 23979                     Fresh Fruit Basket Cobbler     4.5
# 23980                                 Cinnamon Bread     4.6
#
#               total_time       servings  calories  fat carbs protein  \
# 0      1 hour 20 minutes  8–12 servings       NaN  NaN   NaN     NaN
# 1                 1 hour     4 servings       NaN  NaN   NaN     NaN
# 2                    NaN     4 servings       NaN  NaN   NaN     NaN
# 3             30 minutes     4 servings       NaN  NaN   NaN     NaN
# 4                    NaN  Makes 1 dozen       NaN  NaN   NaN     NaN
# ...                  ...            ...       ...  ...   ...     ...
# 23976            30 mins              4     623.0  40g   32g     28g
# 23977            20 mins              4     139.0  14g    4g      1g
# 23978               1 hr              5     442.0  26g   27g     22g
# 23979               1 hr              8     358.0   8g   69g      5g
# 23980       1 hr 10 mins             12     218.0   6g   36g      4g
#
#         category rating_count cook_time              yield  ingredient_count  \
# 0            NaN          NaN       NaN                NaN                18
# 1            NaN          NaN       NaN                NaN                 8
# 2            NaN          NaN       NaN                NaN                13
# 3            NaN          NaN       NaN                NaN                 9
# 4            NaN          NaN       NaN                NaN                13
# ...          ...          ...       ...                ...               ...
# 23976    Recipes          339   20 mins                NaN                 3
# 23977  Side Dish           71    5 mins                NaN                 5
# 23978    Recipes          712   15 mins                NaN                14
# 23979    Recipes            2   20 mins   1 8x13-inch dish                10
# 23980    Recipes        1,154   50 mins  1 (9x5-inch) loaf                13
#
#        verb_count
# 0              30
# 1               8
# 2              26
# 3              37
# 4              17
# ...           ...
# 23976          14
# 23977           8
# 23978          22
# 23979          15
# 23980          16
#
# [23981 rows x 16 columns]

# %%
data['yield_servings_merge'] = data['yield' if data['yield'].empty else 'servings']

# %%
data
# Out:
#                                              ingredients  \
# 0      ['½ cup (63 g) all-purpose flour', '¼ cup (50 ...
# 1      ['4 large red plums (about 1 lb.), cut into ½"...
# 2      ['2 heads of Little Gem lettuce, trimmed, quar...
# 3      ['3 large egg yolks', '4 oz. Pecorino Romano, ...
# 4      ['2 large eggs', '10 Tbsp. unsalted butter, me...
# ...                                                  ...
# 23976  ['1 ⅓ cups French-fried onions, crushed', '1 l...
# 23977  ['2  summer squash, ends trimmed', '¼ cup oliv...
# 23978  ['1 (8 ounce) container ricotta cheese', '2 la...
# 23979  ['2 cups sliced fresh peaches', '2 cups sliced...
# 23980  ['2 cups all-purpose flour', '1 cup white suga...
#
#                                               directions  \
# 0      ['Streusel - Step 1: Whisk , , , and in a medi...
# 1      ['None - Step 1: Bring , , , , and ¼ cup water...
# 2      ['None - Step 1: Place , in a large bowl and c...
# 3      ['None - Step 1: Whisk and , in a medium bowl ...
# 4      ['None - Step 1: Preheat oven to 375°. Line a ...
# ...                                                  ...
# 23976  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23977  ['Preheat the oven to 450 degrees F (230 degre...
# 23978  ['Gather all ingredients.', 'Dotdash Meredith ...
# 23979  ['Preheat oven to 350 degrees F (175 degrees C...
# 23980  ['Preheat the oven to 350 degrees F (175 degre...
#
#                                                title  rating  \
# 0                       Butternut Squash Coffee Cake     4.0
# 1                   Jammy Cumin Plums and Feta Salad     4.7
# 2                     Cheese-Cracker-Crusted Chicken     4.8
# 3                Easy, Cheesy, Almost-Carbonara Udon     5.0
# 4      Butternut Squash, Coconut, and Ginger Muffins     4.4
# ...                                              ...     ...
# 23976                   Crunchy French Onion Chicken     4.5
# 23977                          Roasted Summer Squash     4.7
# 23978                                Ricotta Gnocchi     4.5
# 23979                     Fresh Fruit Basket Cobbler     4.5
# 23980                                 Cinnamon Bread     4.6
#
#               total_time       servings  calories  fat carbs protein  \
# 0      1 hour 20 minutes  8–12 servings       NaN  NaN   NaN     NaN
# 1                 1 hour     4 servings       NaN  NaN   NaN     NaN
# 2                    NaN     4 servings       NaN  NaN   NaN     NaN
# 3             30 minutes     4 servings       NaN  NaN   NaN     NaN
# 4                    NaN  Makes 1 dozen       NaN  NaN   NaN     NaN
# ...                  ...            ...       ...  ...   ...     ...
# 23976            30 mins              4     623.0  40g   32g     28g
# 23977            20 mins              4     139.0  14g    4g      1g
# 23978               1 hr              5     442.0  26g   27g     22g
# 23979               1 hr              8     358.0   8g   69g      5g
# 23980       1 hr 10 mins             12     218.0   6g   36g      4g
#
#         category rating_count cook_time              yield  ingredient_count  \
# 0            NaN          NaN       NaN                NaN                18
# 1            NaN          NaN       NaN                NaN                 8
# 2            NaN          NaN       NaN                NaN                13
# 3            NaN          NaN       NaN                NaN                 9
# 4            NaN          NaN       NaN                NaN                13
# ...          ...          ...       ...                ...               ...
# 23976    Recipes          339   20 mins                NaN                 3
# 23977  Side Dish           71    5 mins                NaN                 5
# 23978    Recipes          712   15 mins                NaN                14
# 23979    Recipes            2   20 mins   1 8x13-inch dish                10
# 23980    Recipes        1,154   50 mins  1 (9x5-inch) loaf                13
#
#        verb_count yield_servings_merge
# 0              30        8–12 servings
# 1               8           4 servings
# 2              26           4 servings
# 3              37           4 servings
# 4              17        Makes 1 dozen
# ...           ...                  ...
# 23976          14                    4
# 23977           8                    4
# 23978          22                    5
# 23979          15                    8
# 23980          16                   12
#
# [23981 rows x 17 columns]
